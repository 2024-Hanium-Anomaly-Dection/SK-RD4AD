# %%
# %cd /content/drive/MyDrive/han/AD_Model/

# %%
# !pip install -r requirements.txt

# %%
# %cd /content/drive/MyDrive/han/AD_Model/

# %%
# !python main.py

# %%
from test import evaluation, visualization, test
